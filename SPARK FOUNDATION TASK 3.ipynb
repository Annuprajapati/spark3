# %% [markdown]
# # \# GRIP:The Sparks Foundation
# Data Science and Business Analytics Intern
# Author: Sachin Rai
# Task 3 Exploratory Data Analysis (EDA)- Retail
# Step -1: Importing the required Libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 2) Importing the dataset

# %%
sample = pd.read_csv("C:\\Users\\Asus Bq512TS\\Downloads\\SampleSuperstore.csv")
sample.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sample.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# # Step-3 Check Data types

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sample.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # Step - 4 Checking for any Null Values in the columns and duplicates values

# %%
sample.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
## Deleting Duplicates if any
sample.drop_duplicates(inplace=True)

# %%
## founding out any duplicates left from the sample file
sample.duplicated().sum()
# Out:
# 0

# %%
## Displaying the unique data
sample.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
##Dropping of Irrelevant columns like we have postal code in the sample file
col =['Postal Code']
drop =sample.drop(columns=col, axis=1, inplace =True)

# %%
sample
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # data visulisation

# %%
plt.figure(figsize=(20,10))
plt.bar("Sub-Category","Category",data=sample)
plt.title("Category vs Sub-Category ")
plt.xlabel("Category")
plt.ylabel("Sub-Category")
plt.show()

# %%
plt.subplot(121)

plt.hist(sample["Category"])
plt.show()

plt.subplot(222)
plt.hist(sample["Profit"])
plt.show()


plt.subplot(223)
plt.hist(sample["Ship Mode"])
plt.show()


plt.subplot(323)
plt.hist(sample["Sales"])
plt.show()

# %%
## Counting repeatable states in the sample file
sample['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,20))
sns.countplot(x=sample['State'])
plt.title('States')
plt.xticks(rotation=80)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.lineplot(x="Discount", y="Profit", data=sample, color='b', label='Profit vs Discount')  # Updated the label here
plt.legend()
plt.show()

# %% [markdown]
# # Now lets Analysis the sales of few states in terms of high profit, medium, loss

# %% [markdown]
# # After the Analysis we can get the answers for questions like
# 1) Which state has most sale and what Category has more demand (i.e CALIFORNIA HAS Highest SALE)
# 2) What are the products that are going into loss due to less or no demand(i.e Taxes)
# 3) Which product need more improvement to make the sales drive higher

# %%
def state_data_viewer(states):
    """plots the turnover generated by different product categories and sub-categories for the list of given states
    Args:
       states -List all the states you want to plot for
       Returns:
       None
       """
    product_data = sample.groupby(['State'])
    for state in states:
        data = product_data.get_group(state).groupby(['Category'])
        fig,ax =plt.subplots(1, 3, figsize= (30,4))
        fig.suptitle(state, fontsize=14)
        ax_index =0
        for cat in ['Furniture', 'Office Supplies', 'Technology']:
            cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
            sns.barplot(x=cat_data.Profit, y= cat_data.index, ax =ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index+=1

        fig.show()

# %%
states =['California', 'Mississippi', 'Texas','Washington','Arizona']
state_data_viewer(states)
# Out:
# C:\Users\Asus Bq512TS\AppData\Local\Temp\ipykernel_6132\3501916323.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
# C:\Users\Asus Bq512TS\AppData\Local\Temp\ipykernel_6132\3501916323.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cat_data = data.get_group(cat).groupby(['Sub-Category']).sum()
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
# Replace 'data' with your actual DataFrame name
data = sample[['State', 'Category', 'Sales', 'Profit']]

# Grouping and aggregating data
agg_data = data.groupby(['State', 'Category']).sum().reset_index()

# Creating a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(agg_data.pivot('State', 'Category', 'Sales'), annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Sales by State and Category')
plt.show()

plt.figure(figsize=(12, 8))
sns.heatmap(agg_data.pivot('State', 'Category', 'Profit'), annot=True, fmt=".2f", cmap="YlOrRd")
plt.title('Profit by State and Category')
plt.show()
# Out:
# C:\Users\Asus Bq512TS\AppData\Local\Temp\ipykernel_6132\587088074.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(agg_data.pivot('State', 'Category', 'Sales'), annot=True, fmt=".2f", cmap="YlGnBu")
# C:\Users\Asus Bq512TS\AppData\Local\Temp\ipykernel_6132\587088074.py:18: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(agg_data.pivot('State', 'Category', 'Profit'), annot=True, fmt=".2f", cmap="YlOrRd")

# %% [markdown]
# data Visualization we can see that states and category where sale and profit are high and less.
# We can improve the profit in other states where there is low sale or profit by giving discount and various offers.
